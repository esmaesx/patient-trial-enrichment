# %% [markdown]
# # Patient Trial Enrichment — Overview
#
# This notebook walks through a demo of trial enrichment using open data + a simulated cohort.
#
# **Scope (honest + simple):**
# - Build a PRS-style score from public GWAS summary stats
# - Add basic clinical covariates (age/sex)
# - Simulate enrichment and visualize yield
#
# **Methods (high-level):**
# - Harmonize GWAS summary stats → PRS-style score
# - Add basic clinical covariates
# - Simulate enrichment and quantify screening yield
#
# This is **not** clinical advice.
